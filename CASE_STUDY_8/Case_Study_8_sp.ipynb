# %%
import numpy as np
import pandas as pd 
#import fbprophet 
#from fbprophet import Prophet
import plotly
import statsmodels
from statsmodels.tsa.stattools import acf
from matplotlib import pyplot
import altair as alt
import scipy
from scipy import signal
#import spectrum 
#from spectrum import WelchPeriodogram
#from spectrum import Periodogram
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import q_stat
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_process import arma_generate_sample
from statsmodels.tsa.stattools import arma_order_select_ic
import statsmodels.api as sm
from math import sqrt
import warnings
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
                        FutureWarning)
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
                        FutureWarning)

# %%
flu_data = pd.read_csv('flu.csv', header = 2, sep = ',')

# %%
flu_data.head(n=5)
# Out:
#                     Country                      WHOREGION      FLUREGION  \
# 0  United States of America  Region of the Americas of WHO  North America
# 1  United States of America  Region of the Americas of WHO  North America
# 2  United States of America  Region of the Americas of WHO  North America
# 3  United States of America  Region of the Americas of WHO  North America
# 4  United States of America  Region of the Americas of WHO  North America
#
#    Year  Week       SDATE       EDATE  SPEC_RECEIVED_NB  SPEC_PROCESSED_NB  \
# 0  2013     1  2012-12-31  2013-01-06             18219              18219
# 1  2013     2  2013-01-07  2013-01-13             20013              20013
# 2  2013     3  2013-01-14  2013-01-20             19228              19228
# 3  2013     4  2013-01-21  2013-01-27             17139              17139
# 4  2013     5  2013-01-28  2013-02-03             14795              14795
#
#    AH1  ...  AH5  ANOTSUBTYPED  INF_A  BYAMAGATA  BVICTORIA  BNOTDETERMINED  \
# 0  0.0  ...  0.0          1653   5377          0          0            1097
# 1  0.0  ...  0.0          1767   5752          0          0            1145
# 2  0.0  ...  0.0          1624   4858          0          0            1078
# 3  0.0  ...  0.0          1528   4039          0          0            1091
# 4  0.0  ...  0.0           951   2963          0          0            1076
#
#    INF_B  ALL_INF  ALL_INF2                TITLE
# 0   1097     6474       NaN  Widespread Outbreak
# 1   1145     6897       NaN  Widespread Outbreak
# 2   1078     5936       NaN  Widespread Outbreak
# 3   1091     5130       NaN  Widespread Outbreak
# 4   1076     4039       NaN  Widespread Outbreak
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Utility Functions

# %% [markdown]
# ### Adapted from
#
# ###### https://www.statsmodels.org/devel/examples/notebooks/generated/statespace_forecasting.html
#
# ###### https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/

# %%
def arima_window_ase(data_series, train_ratio = .60, order = (0,0,0), seasonal_order = (0,0,0,0)): 
    X_series = data_series.values
    size = int(len(X_series)*train_ratio)
    train,test = X_series[0:size], X_series[size:len(X_series)]
    history = [i for i in train]
    preds = list()
    for t in range(len(test)): 
        model = ARIMA(history, order=order)
        model_fit = model.fit()
        fore_cast = model_fit.forecast()
        yhat = fore_cast[0]
        preds.append(yhat)
        obs = test[t]
        history.append(obs)
    rmse = sqrt(mean_squared_error(test, preds))
    pyplot.plot(test)
    pyplot.plot(preds, color='red')
    pyplot.show()
    
    return rmse
    print(residuals.describe())

# %%
def make_realization(data_frame,x,y): 
    
    vis = alt.Chart(data_frame).mark_line().encode(
    x = x, 
    y = y
    )
    
    return vis

# %%
def make_autocorr(data_series, nlags=40, fft = False): 
    auto_corr = statsmodels.tsa.stattools.acf(data_series, nlags=nlags, fft=fft)
    data = pd.DataFrame(list(enumerate(auto_corr)), columns = ['Lag', 'AutoCor'])
    vis = alt.Chart(data).mark_bar().encode(
    x='Lag',
    y='AutoCor',
    )
    return vis

# %%
def make_sig_periodgram(data_series, fs = 1, scaling = 'density'): 
    f, Pxx_den = scipy.signal.periodogram(data_series, fs = fs, scaling=scaling)
    data = pd.DataFrame({'Freq' : f,'Density' : Pxx_den})
    vis = alt.Chart(data).mark_bar().encode(
        x='Freq',
        y='Density',
    )
    return vis

# %%
def make_welch_sig_periodgram(data_series, fs = 1, nperseg=50): 
    f, Pxx_den = scipy.signal.welch(flu_data.SPEC_RECEIVED_NB, fs = 1, nperseg=nperseg)
    data = pd.DataFrame({'Freq' : f,'Density' : Pxx_den})
    vis = alt.Chart(data).mark_bar().encode(
        x='Freq',
        y='Density',
    )
    return vis

# %%
def make_welch_periodgram(data_series, sampling = 50):
    psd = WelchPeriodogram(data_series, sampling)
    return psd[1]

# %% [markdown]
# ### Function call to realization generations

# %%
make_realization(flu_data, 'EDATE:T', 'ALL_INF')
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# ### Under the hood this is what the make_realization function does

# %%
alt.Chart(flu_data).mark_line().encode(
    x='EDATE:T',
    y='ALL_INF'
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# ### To verify if variable is a series

# %%
series = flu_data.ALL_INF
series.index
# Out:
# RangeIndex(start=0, stop=423, step=1)

# %% [markdown]
# ### Function call to generate autocorrelation plot
# ### we can see there is evidence against stationarity, there is slowly dampening sinusiodal autocorrelations

# %%
make_autocorr(flu_data.ALL_INF, nlags = 40)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# ### Under the hood this is what the make_autocorr function does

# %%
ALL_INF_auto_cor = statsmodels.tsa.stattools.acf(flu_data.ALL_INF)
# Out:
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\stattools.py:568: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(

# %%
data = pd.DataFrame(list(enumerate(ALL_INF_auto_cor)), columns = ['Lag', 'AutoCor'])
alt.Chart(data).mark_bar().encode(
    x='Lag',
    y='AutoCor',
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# ### Make function call to series periodgram to see if underlying frequency exists

# %%
make_sig_periodgram(flu_data.ALL_INF)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# ### ### Under the hood this is what the make_sig_periodgram function does

# %%
f, Pxx_den = scipy.signal.periodogram(flu_data.ALL_INF, fs = 1, scaling='density')

# %%
data = pd.DataFrame({'Freq' : f,'Density' : Pxx_den})
alt.Chart(data).mark_bar().encode(
    x='Freq',
    y='Density',
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# ### make function call to make_welch_sig_perdiogram function

# %%
make_welch_sig_periodgram(flu_data.ALL_INF, fs = 1, nperseg=420)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# ### Under the hood this is what the make_realization function does

# %%
f, Pxx_den = scipy.signal.welch(flu_data.ALL_INF, fs = 1, nperseg=420)

# %%
data = pd.DataFrame({'Freq' : f,'Density' : Pxx_den})
alt.Chart(data).mark_bar().encode(
    x='Freq',
    y='Density',
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# ### function call to welch Power Spectral Density plot function

# %%
make_welch_periodgram(flu_data.ALL_INF,sampling = 50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-1199052bbffb> in <module>
# ----> 1 make_welch_periodgram(flu_data.ALL_INF,sampling = 50)
#
# <ipython-input-20-c29ba0bc641b> in make_welch_periodgram(data_series, sampling)
#       1 def make_welch_periodgram(data_series, sampling = 50):
# ----> 2     psd = WelchPeriodogram(data_series, sampling)
#       3     return psd[1]
#
# NameError: name 'WelchPeriodogram' is not defined

# %% [markdown]
# ### Under the hood this is what the make_welch_periodgram function does

# %%
psd = WelchPeriodogram(flu_data.ALL_INF,50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-a46d638e9960> in <module>
# ----> 1 psd = WelchPeriodogram(flu_data.ALL_INF,50)
#
# NameError: name 'WelchPeriodogram' is not defined

# %%
psd = Periodogram(flu_data.ALL_INF, 50, scale_by_freq = True)
psd.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-b4fdaae4e543> in <module>
# ----> 1 psd = Periodogram(flu_data.ALL_INF, 50, scale_by_freq = True)
#       2 psd.plot()
#
# NameError: name 'Periodogram' is not defined

# %% [markdown]
# ### Lets get an estimate of our arma model structure, assuming stationarity despite evidence against

# %%
res = statsmodels.tsa.stattools.arma_order_select_ic(flu_data.ALL_INF, ic=["aic", "bic"], trend="nc")
# Out:
# /home/andrew/Documents/qtw/env/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /home/andrew/Documents/qtw/env/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /home/andrew/Documents/qtw/env/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /home/andrew/Documents/qtw/env/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /home/andrew/Documents/qtw/env/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /home/andrew/Documents/qtw/env/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /home/andrew/Documents/qtw/env/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /home/andrew/Documents/qtw/env/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /home/andrew/Documents/qtw/env/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
res.aic
# Out:
#              0            1            2
# 0          NaN  9340.380969  8935.618407
# 1  8137.488407  8028.267909  7989.563702
# 2  7985.137073  7986.159993  7984.675115
# 3  7986.216854  7983.348112  7984.749204
# 4  7988.216563  7984.104760  7971.680217

# %%
res.aic_min_order
# Out:
# (4, 2)

# %%
res.bic
# Out:
#              0            1            2
# 0          NaN  9348.475713  8947.760524
# 1  8145.583151  8040.410025  8005.753190
# 2  7997.279190  8002.349482  8004.911976
# 3  8002.406343  8003.584973  8009.033437
# 4  8008.453424  8008.388994  8000.011822

# %%
res.bic_min_order
# Out:
# (2, 0)

# %% [markdown]
# ### AIC and BIC differ, but we will go with BIC model structure, suggesting the errors are Gaussian, but maylook to be centered on zero. We see the errors still look correlated and there is some trend the model is not capturing.

# %%
model = ARIMA(flu_data.SPEC_RECEIVED_NB, order=(2,0,0))
model_fit = model.fit()
# summary of fit model
print(model_fit.summary())
# line plot of residuals
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
# density plot of residuals
residuals.plot(kind='kde')
pyplot.show()
# summary stats of residuals
print(residuals.describe())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       SPEC_RECEIVED_NB   No. Observations:                  423
# Model:                 ARIMA(2, 0, 0)   Log Likelihood               -3985.131
# Date:                Sat, 20 Feb 2021   AIC                           7978.263
# Time:                        10:04:59   BIC                           7994.452
# Sample:                             0   HQIC                          7984.660
#                                 - 423
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.131e+04   8613.545      2.474      0.013    4428.421    3.82e+04
# ar.L1          1.5316      0.024     65.133      0.000       1.485       1.578
# ar.L2         -0.5602      0.022    -25.103      0.000      -0.604      -0.516
# sigma2      8.875e+06    181.059    4.9e+04      0.000    8.88e+06    8.88e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.48   Jarque-Bera (JB):             10140.10
# Prob(Q):                              0.49   Prob(JB):                         0.00
# Heteroskedasticity (H):              16.53   Skew:                             0.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                        26.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.96e+25. Standard errors may be unstable.
#                   0
# count    423.000000
# mean      11.453362
# std     2980.691003
# min   -26331.120360
# 25%     -861.404582
# 50%     -356.491900
# 75%      489.911810
# max    22381.314924

# %% [markdown]
# H0: The data are independently distributed (i.e. the correlations in the population from which the sample is taken are 0, so that any observed correlations in the data result from randomness of the sampling process).
# Ha: The data are not independently distributed; they exhibit serial correlation.
#
# We can see at Lag 10 there is sufficient evidence to say the residuals are not idependently distributed, and supports serial correlation. But that does not mean the model is not useful.

# %%
 sm.stats.acorr_ljungbox(model_fit.resid, lags=[10], return_df=True)
# Out:
#       lb_stat  lb_pvalue
# 10  34.945156   0.000128

# %% [markdown]
# ### Function call to arima_window_ase
# ### We can see the model does follow the data well.

# %%
arima_window_ase(flu_data.SPEC_RECEIVED_NB, train_ratio = .80, order=(2,0,0))
# Out:
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-13501c0710eb> in <module>
# ----> 1 arima_window_ase(flu_data.SPEC_RECEIVED_NB, train_ratio = .80, order=(4,0,2))
#
# <ipython-input-7-8d6eb4a68548> in arima_window_ase(data_series, train_ratio, order)
#       7     for t in range(len(test)):
#       8         model = ARIMA(history, order=order)
# ----> 9         model_fit = model.fit()
#      10         fore_cast = model_fit.forecast()
#      11         yhat = fore_cast[0]
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\arima\model.py in fit(self, start_params, transformed, includes_fixed, method, method_kwargs, gls, gls_kwargs, cov_type, cov_kwds, return_params, low_memory)
#     323                 method_kwargs.setdefault('disp', 0)
#     324
# --> 325                 res = super(ARIMA, self).fit(return_params=return_params,
#     326                                              low_memory=low_memory,
#     327                                              **method_kwargs)
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     652                 flags['hessian_method'] = optim_hessian
#     653             fargs = (flags,)
# --> 654             mlefit = super(MLEModel, self).fit(start_params, method=method,
#     655                                                fargs=fargs,
#     656                                                maxiter=maxiter,
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     516         warn_convergence = kwargs.pop('warn_convergence', True)
#     517         optimizer = Optimizer()
# --> 518         xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     519                                                        fargs, kwargs,
#     520                                                        hessian=hess,
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     213
#     214         func = fit_funcs[method]
# --> 215         xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     216                             disp=disp, maxiter=maxiter, callback=callback,
#     217                             retall=retall, full_output=full_output,
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     435         func = f
#     436
# --> 437     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     438                                      callback=callback, args=fargs,
#     439                                      bounds=bounds, disp=disp,
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\scipy\optimize\lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     195             'maxls': maxls}
#     196
# --> 197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                            **opts)
#     199     d = {'grad': res['jac'],
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_and_grad(self, x)
#     199             self._update_x_impl(x)
#     200         self._update_fun()
# --> 201         self._update_grad()
#     202         return self.f, self.g
#     203
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_grad(self)
#     169     def _update_grad(self):
#     170         if not self.g_updated:
# --> 171             self._update_grad_impl()
#     172             self.g_updated = True
#     173
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_grad()
#      89                 self._update_fun()
#      90                 self.ngev += 1
# ---> 91                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#      92                                            **finite_diff_options)
#      93
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\scipy\optimize\_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     424
#     425         if sparsity is None:
# --> 426             return _dense_difference(fun_wrapped, x0, f0, h,
#     427                                      use_one_sided, method)
#     428         else:
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\scipy\optimize\_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     495             x = x0 + h_vecs[i]
#     496             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 497             df = fun(x) - f0
#     498         elif method == '3-point' and use_one_sided[i]:
#     499             x1 = x0 + h_vecs[i]
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\scipy\optimize\_numdiff.py in fun_wrapped(x)
#     375
#     376     def fun_wrapped(x):
# --> 377         f = np.atleast_1d(fun(x, *args, **kwargs))
#     378         if f.ndim > 1:
#     379             raise RuntimeError("`fun` return value has "
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py in f(params, *args)
#     498
#     499         def f(params, *args):
# --> 500             return -self.loglike(params, *args) / nobs
#     501
#     502         if method == 'newton':
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in loglike(self, params, *args, **kwargs)
#     887             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     888
# --> 889         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     890
#     891         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in loglike(self, **kwargs)
#     975         kwargs.setdefault('conserve_memory',
#     976                           MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# --> 977         kfilter = self._filter(**kwargs)
#     978         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     979                                         self.loglikelihood_burn)
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     895
#     896         # Initialize the state
# --> 897         self._initialize_state(prefix=prefix, complex_step=complex_step)
#     898
#     899         # Run the filter
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\statespace\representation.py in _initialize_state(self, prefix, complex_step)
#     947             if not self.initialization.initialized:
#     948                 raise RuntimeError('Initialization is incomplete.')
# --> 949             self._statespaces[prefix].initialize(self.initialization,
#     950                                                  complex_step=complex_step)
#     951         else:
#
# statsmodels\tsa\statespace\_representation.pyx in statsmodels.tsa.statespace._representation.dStatespace.initialize()
#
# ~\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\statespace\initialization.py in _initialize_initialization(self, prefix)
#     230                 self.constant.astype(dtype)[:])
#     231             self._representations[prefix]['stationary_cov'][:] = (
# --> 232                 self.stationary_cov.astype(dtype)[:])
#     233
#     234         # Create if necessary
#
# KeyboardInterrupt:

# %%
arima_window_ase(flu_data.SPEC_RECEIVED_NB, train_ratio = .80, order=(4,1,2))
# Out:
# /home/andrew/Documents/qtw/env/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/andrew/Documents/qtw/env/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/andrew/Documents/qtw/env/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# 5583.778779665173

# %% [markdown]
# ### Under the hood this is what the arima_window_ASE does

# %%
X = flu_data.SPEC_RECEIVED_NB.values
size = int(len(X) * 0.80)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# window MSE 
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
# evaluate forecasts
rmse = sqrt(mean_squared_error(test, predictions))
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()

# %%
rmse
# Out:
# 5682.187290641301

# %%
m = Prophet()
Prophet_df = flu_data[['EDATE','SPEC_RECEIVED_NB']].copy()
Prophet_df['EDATE'] = Prophet_df['EDATE'].astype('datetime64[ns]')
Prophet_df.columns = ['ds', 'y']
Prophet_df.info()
m.fit(Prophet_df)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      423 non-null    datetime64[ns]
#  1   y       423 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 6.7 KB

# %%
future = m.make_future_dataframe(periods=50)
future.tail()
# Out:
#             ds
# 468 2021-03-25
# 469 2021-03-26
# 470 2021-03-27
# 471 2021-03-28
# 472 2021-03-29

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds          yhat    yhat_lower    yhat_upper
# 468 2021-03-25  47312.797090  35662.136984  59561.206170
# 469 2021-03-26  46713.763190  34153.932707  58695.716295
# 470 2021-03-27  46086.452479  33521.391480  58926.273918
# 471 2021-03-28  45434.216927  32973.651567  58173.219817
# 472 2021-03-29  44760.846220  33227.726494  56720.504046

# %% [markdown]
# ########################### SABRINA ######################################

# %%
flu_data.head()
# Out:
#                     Country                      WHOREGION      FLUREGION  \
# 0  United States of America  Region of the Americas of WHO  North America
# 1  United States of America  Region of the Americas of WHO  North America
# 2  United States of America  Region of the Americas of WHO  North America
# 3  United States of America  Region of the Americas of WHO  North America
# 4  United States of America  Region of the Americas of WHO  North America
#
#    Year  Week       SDATE       EDATE  SPEC_RECEIVED_NB  SPEC_PROCESSED_NB  \
# 0  2013     1  2012-12-31  2013-01-06             18219              18219
# 1  2013     2  2013-01-07  2013-01-13             20013              20013
# 2  2013     3  2013-01-14  2013-01-20             19228              19228
# 3  2013     4  2013-01-21  2013-01-27             17139              17139
# 4  2013     5  2013-01-28  2013-02-03             14795              14795
#
#    AH1  ...  AH5  ANOTSUBTYPED  INF_A  BYAMAGATA  BVICTORIA  BNOTDETERMINED  \
# 0  0.0  ...  0.0          1653   5377          0          0            1097
# 1  0.0  ...  0.0          1767   5752          0          0            1145
# 2  0.0  ...  0.0          1624   4858          0          0            1078
# 3  0.0  ...  0.0          1528   4039          0          0            1091
# 4  0.0  ...  0.0           951   2963          0          0            1076
#
#    INF_B  ALL_INF  ALL_INF2                TITLE
# 0   1097     6474       NaN  Widespread Outbreak
# 1   1145     6897       NaN  Widespread Outbreak
# 2   1078     5936       NaN  Widespread Outbreak
# 3   1091     5130       NaN  Widespread Outbreak
# 4   1076     4039       NaN  Widespread Outbreak
#
# [5 rows x 22 columns]

# %%
acf(flu_data.ALL_INF)
# Out:
# array([ 1.        ,  0.97340255,  0.91161694,  0.82928864,  0.73597795,
#         0.6349297 ,  0.52424732,  0.40975496,  0.29893333,  0.19859855,
#         0.1119284 ,  0.03595709, -0.03226184, -0.09113685, -0.13894138,
#        -0.17683985, -0.20683848, -0.23069557, -0.24896327, -0.26266285,
#        -0.2727453 , -0.28017243, -0.28574246, -0.28991645, -0.29292166,
#        -0.29497416, -0.29601989, -0.29585006, -0.29452285, -0.29193081,
#        -0.28779058, -0.28180849, -0.27339102, -0.26211158, -0.24697497,
#        -0.22725203, -0.20190621, -0.17037865, -0.13187261, -0.08643847,
#        -0.03504717])

# %%
statsmodels.tsa.stattools.adfuller(flu_data.ALL_INF) #this indicates stationarity - the second listed value is the pvalue, which is less than .05
# Out:
# (-5.118847930322406,
#  1.2845833630233787e-05,
#  14,
#  408,
#  {'1%': -3.446479704252724,
#   '5%': -2.8686500930967354,
#   '10%': -2.5705574627547096},
#  6617.007967071611)

# %%
statsmodels.graphics.tsaplots.plot_acf(flu_data.ALL_INF, lags = 200) #by expanding out the lags, I can see the 52 week (annual) seasonality

# %%
#Now I want to factor out the seasonality
flu_s52 = statsmodels.tsa.statespace.tools.diff(flu_data.ALL_INF, seasonal_periods=52)

# %%
statsmodels.graphics.tsaplots.plot_acf(flu_s52)

# %%
#now we run aic to find the arma components
#expanded out the phi and theta thresholds since prior runs maximized both 
res = statsmodels.tsa.stattools.arma_order_select_ic(flu_s52, max_ar=15, max_ma=8, ic=["aic","bic"])
# Out:
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\tsatools.py:672: RuntimeWarning: invalid value encountered in arctanh
#   invarcoefs = 2*np.arctanh(params)
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\tsatools.py:716: RuntimeWarning: invalid value encountered in log
#   invmacoefs = -np.log((1-macoefs)/(1+macoefs))
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\tsatools.py:714: RuntimeWarning: divide by zero encountered in double_scalars
#   tmp[kiter] = (macoefs[kiter]-b *macoefs[j-kiter-1])/(1-b**2)
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\tsatools.py:714: RuntimeWarning: invalid value encountered in double_scalars
#   tmp[kiter] = (macoefs[kiter]-b *macoefs[j-kiter-1])/(1-b**2)
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\tsatools.py:716: RuntimeWarning: invalid value encountered in true_divide
#   invmacoefs = -np.log((1-macoefs)/(1+macoefs))
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\tsatools.py:716: RuntimeWarning: divide by zero encountered in log
#   invmacoefs = -np.log((1-macoefs)/(1+macoefs))
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\scipy\optimize\_numdiff.py:410: RuntimeWarning: invalid value encountered in subtract
#   dx = ((x0 + h) - x0)
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\scipy\optimize\_numdiff.py:496: RuntimeWarning: invalid value encountered in double_scalars
#   dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "

# %%
res.aic
# Out:
#               0            1            2            3            4  \
# 0   7219.193907  7021.263970  6970.434788  6947.453781  6946.680843
# 1   6959.362711  6956.589884  6955.259534  6944.038617  6935.864193
# 2   6956.025318  6957.939997  6956.870320  6958.855098  6934.852626
# 3   6957.796060  6959.567194  6941.251814  6941.119623  6939.228646
# 4   6956.661705  6957.579632  6941.110836  6943.068331  6941.402028
# 5   6951.381567  6944.030099  6938.979551  6939.305210  6934.993432
# 6   6929.545357  6920.500946  6906.780804  6907.050555  6907.262320
# 7   6925.915440  6904.042278  6904.975816  6908.988167  6911.048901
# 8   6923.674350  6905.254043  6906.967351  6907.190146  6902.103588
# 9   6923.652353  6925.427604  6918.610077  6898.593096  6898.191255
# 10  6925.136961  6927.118193  6919.175915  6897.210566          NaN
# 11  6926.980213  6927.631776  6920.828614  6899.165059          NaN
# 12  6921.947519  6923.884341  6921.341572  6901.880529  6895.168803
# 13  6923.830975  6924.506637  6922.649788  6903.815020  6904.537273
# 14  6924.276177  6925.387355  6924.609410  6901.665525  6907.198494
# 15  6923.051485  6902.984902  6924.243973  6905.381923  6904.248751
#
#               5            6            7            8
# 0   6940.514473  6937.009419  6937.439138  6929.862238
# 1   6934.887207  6936.131785  6937.533354  6931.611016
# 2   6933.373225  6908.142444  6927.354349  6917.865832
# 3   6933.330861  6935.305314  6911.070736  6919.830514
# 4   6910.825131  6935.029827  6920.134663  6921.103750
# 5   6933.002305  6934.951095  6921.718114  6922.934678
# 6   6934.264862  6936.306642  6922.485144  6897.935242
# 7   6910.694900  6906.077120  6903.936032  6909.071718
# 8   6897.844669  6899.832112  6901.671092  6900.586095
# 9           NaN  6901.309540  6903.099095  6902.195142
# 10  6894.004209  6902.803237  6904.682339  6904.136482
# 11          NaN  6903.425765  6909.108688  6901.905472
# 12  6901.882088  6894.824528  6907.379420  6897.103342
# 13  6907.196950          NaN  6907.167489  6901.674607
# 14  6900.143743          NaN          NaN  6899.135119
# 15  6906.803440          NaN  6904.488989  6903.192471

# %%
res.aic_min_order
# Out:
# (10, 5)

# %%
res.bic
# Out:
#               0            1            2            3            4  \
# 0   7227.283917  7033.398986  6986.614809  6967.678808  6970.950875
# 1   6971.497727  6972.769905  6975.484560  6968.308649  6964.179231
# 2   6972.205340  6978.165024  6981.140352  6987.170135  6967.212668
# 3   6978.021086  6983.837225  6969.566851  6973.479666  6975.633694
# 4   6980.931737  6985.894670  6973.470879  6979.473378  6981.852081
# 5   6979.696604  6976.390141  6975.384599  6979.755263  6979.488490
# 6   6961.905400  6956.905994  6947.230857  6951.545613  6955.802384
# 7   6962.320487  6944.492331  6949.470874  6957.528231  6963.633970
# 8   6964.124403  6949.749102  6955.507414  6959.775215  6958.733662
# 9   6968.147412  6973.967667  6971.195146  6955.223171  6958.866335
# 10  6973.677024  6979.703263  6975.805990  6957.885646          NaN
# 11  6979.565282  6984.261851  6981.503693  6963.885144          NaN
# 12  6978.577593  6984.559421  6986.061657  6970.645620  6967.978898
# 13  6984.506054  6989.226722  6991.414878  6976.625115  6981.392374
# 14  6988.996262  6994.152445  6997.419506  6978.520626  6988.098600
# 15  6991.816575  6975.794997  7001.099074  6986.282029  6989.193862
#
#               5            6            7            8
# 0   6968.829510  6969.369462  6973.844186  6970.312291
# 1   6967.247249  6972.536833  6977.983407  6976.106075
# 2   6969.778273  6948.592497  6971.849407  6966.405896
# 3   6973.780914  6979.800372  6959.610800  6972.415583
# 4   6955.320189  6983.569891  6972.719732  6977.733825
# 5   6981.542369  6987.536164  6978.348188  6983.609757
# 6   6986.849931  6992.936716  6983.160223  6962.655327
# 7   6967.324974  6966.752200  6968.656117  6977.836808
# 8   6958.519749  6964.552197  6970.436182  6973.396191
# 9           NaN  6970.074630  6975.909191  6979.050242
# 10  6962.769299  6975.613333  6981.537440  6985.036588
# 11          NaN  6980.280866  6990.008794  6986.850583
# 12  6978.737189  6975.724634  6992.324532  6986.093459
# 13  6988.097056          NaN  6996.157606  6994.709729
# 14  6985.088855          NaN          NaN  6996.215247
# 15  6995.793557          NaN  7001.569117  7004.317604

# %%
res.bic_min_order
# Out:
# (7, 1)

# %%
#fit the model using AIC
model = ARIMA(flu_data.ALL_INF, order=(10,0,5), seasonal_order=(1,0,1,52))
model_fit = model.fit()
# summary of fit model
print(model_fit.summary())
# line plot of residuals
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
# density plot of residuals
residuals.plot(kind='kde')
pyplot.show()
# summary stats of residuals
print(residuals.describe())
# Out:
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                             ALL_INF   No. Observations:                  423
# Model:             ARIMA(10, 0, 5)x(1, 0, [1], 52)   Log Likelihood               -3432.352
# Date:                             Sun, 21 Feb 2021   AIC                           6902.705
# Time:                                     20:21:36   BIC                           6979.605
# Sample:                                          0   HQIC                          6933.090
#                                              - 423
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3144.9146   1889.874      1.664      0.096    -559.171    6849.000
# ar.L1          0.5333      1.753      0.304      0.761      -2.903       3.969
# ar.L2         -0.2445      2.584     -0.095      0.925      -5.310       4.821
# ar.L3          0.3381      2.649      0.128      0.898      -4.855       5.531
# ar.L4          0.2764      2.900      0.095      0.924      -5.407       5.960
# ar.L5          0.0231      2.001      0.012      0.991      -3.899       3.945
# ar.L6          0.0910      1.480      0.061      0.951      -2.809       2.991
# ar.L7         -0.1223      1.117     -0.109      0.913      -2.311       2.067
# ar.L8         -0.0905      0.846     -0.107      0.915      -1.749       1.569
# ar.L9         -0.2051      0.918     -0.223      0.823      -2.004       1.594
# ar.L10         0.1076      0.411      0.262      0.794      -0.699       0.914
# ma.L1          1.1108      1.750      0.635      0.526      -2.319       4.540
# ma.L2          1.4035      0.578      2.430      0.015       0.271       2.536
# ma.L3          1.1154      1.986      0.562      0.574      -2.777       5.008
# ma.L4          0.5188      0.478      1.086      0.278      -0.418       1.455
# ma.L5          0.3596      0.574      0.626      0.531      -0.766       1.486
# ar.S.L52       0.4610      0.151      3.062      0.002       0.166       0.756
# ma.S.L52      -0.2485      0.170     -1.459      0.144      -0.582       0.085
# sigma2      7.036e+05   2.82e+04     24.970      0.000    6.48e+05    7.59e+05
# ===================================================================================
# Ljung-Box (Q):                        7.55   Jarque-Bera (JB):              1793.18
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.86   Skew:                             0.49
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                  0
# count   423.000000
# mean     -0.042115
# std     816.805969
# min   -4249.640597
# 25%    -194.850655
# 50%    -101.421874
# 75%      78.847943
# max    4791.970169

# %%
#Ljung Box Test
sm.stats.acorr_ljungbox(model_fit.resid, lags=[24], return_df=True)
# Out:
#      lb_stat  lb_pvalue
# 24  3.186419        1.0

# %%
sm.stats.acorr_ljungbox(model_fit.resid, lags=[48], return_df=True)
# Out:
#       lb_stat  lb_pvalue
# 48  30.523999   0.976806

# %%
#rolling window ASE
arima_window_ase(flu_data.ALL_INF, train_ratio = .80, order=(10,0,5), seasonal_order=(1,0,1,52))
# Out:
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\sabri\Anaconda3\envs\ML7331\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# 1170.9824543017166

# %%
fc=model_fit.predict(start=339,end=380,dynamic=False)

# %%
fc
# Out:
# 339      260.246629
# 340      466.586451
# 341      353.816154
# 342      352.993081
# 343      345.025621
# 344      387.085353
# 345      278.248941
# 346      440.458364
# 347      427.036143
# 348      654.428228
# 349      586.794627
# 350      583.736945
# 351      692.790140
# 352      841.448809
# 353      362.685123
# 354      681.898813
# 355      786.286479
# 356     1149.288616
# 357     1354.720635
# 358     3055.817444
# 359     3401.356306
# 360     5694.347637
# 361     5483.354028
# 362     7751.398480
# 363    11156.620960
# 364    18406.759756
# 365    22453.640597
# 366    16282.702376
# 367    15409.536620
# 368    21103.281948
# 369    23924.578002
# 370    26323.370388
# 371    23130.459050
# 372    21946.023591
# 373    18549.327689
# 374    17586.347286
# 375    14325.854439
# 376     8743.814956
# 377      611.696667
# 378    -1860.294030
# 379      500.607796
# 380     -295.868084
# dtype: float64
